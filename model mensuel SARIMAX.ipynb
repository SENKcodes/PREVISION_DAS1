# %%
import pandas as pd
import numpy as np
import openpyxl as xl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.stattools import adfuller
from tabulate import tabulate
from statsmodels.tsa.stattools import acf,pacf
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pm
from pmdarima import auto_arima

# %%
df=pd.read_excel("FS_DATA_DAS.xlsx")
df
# Out:
#           Date      Recettes    Change        IPC
# 0   1998-10-01  4.511900e+08   16.3043   7.497835
# 1   1998-11-01  3.793800e+08   16.5948   8.022774
# 2   1998-12-01  3.967000e+08   16.5046   7.447713
# 3   1999-01-01  4.376500e+08   16.7778   7.375875
# 4   1999-02-01  4.147200e+08   16.8943   7.932369
# ..         ...           ...       ...        ...
# 307 2024-05-01  4.974492e+09  132.5137  28.300000
# 308 2024-06-01  6.102811e+09  132.2823  28.900000
# 309 2024-07-01  4.995281e+09  131.7522  30.000000
# 310 2024-08-01  4.843745e+09  131.5083  29.300000
# 311 2024-09-01  3.547972e+09  131.5920  27.900000
#
# [312 rows x 4 columns]

# %%
# ⚠️ S'assurer que l'index est une date
df.index = pd.to_datetime(df.index)

# ⚠️ Supprimer les valeurs manquantes
df = df[['Recettes', 'IPC', 'Change']].dropna()

# 🧪 Séparer données d'entraînement et test (par exemple, les 12 derniers mois)
train = df[:-12]
test = df[-12:]

# 🔢 Définir les séries
y_train = train['Recettes']
exog_train = train[['IPC', 'Change']]

y_test = test['Recettes']
exog_test = test[['IPC', 'Change']]

# 🔧 Estimer le modèle SARIMAX (exemple : ARIMA(1,1,1) avec saisonnalité annuelle)
model = SARIMAX(
    y_train,
    exog=exog_train,
    order=(1, 1, 1),
    seasonal_order=(1, 1, 1, 12),  # saisonnalité annuelle mensuelle
    enforce_stationarity=False,
    enforce_invertibility=False
)

results = model.fit(disp=False)

# 📈 Résumé
print(results.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                           Recettes   No. Observations:                  300
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -5852.559
# Date:                            Thu, 26 Jun 2025   AIC                          11719.119
# Time:                                    19:31:26   BIC                          11744.385
# Sample:                                01-01-1970   HQIC                         11729.261
#                                      - 01-01-1970
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# IPC        -1.221e+07   7.35e-10  -1.66e+16      0.000   -1.22e+07   -1.22e+07
# Change     -7.981e+06   3.97e-10  -2.01e+16      0.000   -7.98e+06   -7.98e+06
# ar.L1          0.1127      0.063      1.785      0.074      -0.011       0.236
# ma.L1         -0.8467      0.036    -23.255      0.000      -0.918      -0.775
# ar.S.L12      -0.0410      0.112     -0.366      0.714      -0.261       0.179
# ma.S.L12      -0.6546      0.099     -6.613      0.000      -0.849      -0.461
# sigma2       3.25e+17   1.66e-19   1.95e+36      0.000    3.25e+17    3.25e+17
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               710.30
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):              24.93   Skew:                             1.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.65e+51. Standard errors may be unstable.

# %%
df = df[['Recettes', 'IPC', 'Change']].dropna()
df.index = pd.to_datetime(df.index)

# Séparer en train/test
train = df[:-12]
test = df[-12:]

y_train = train['Recettes']
exog_train = train[['IPC', 'Change']]
exog_test = test[['IPC', 'Change']]

# %%
stepwise_model = auto_arima(
    y=y_train,
    exogenous=exog_train,
    seasonal=True,
    m=12,  # fréquence saisonnière (12 pour données mensuelles)
    trace=True,
    error_action='ignore',
    suppress_warnings=True,
    stepwise=True
)

print(stepwise_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=12829.626, Time=1.30 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=12975.345, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=12875.195, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=12849.922, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=12973.475, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=12847.322, Time=0.85 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=12836.660, Time=0.96 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=12829.431, Time=2.75 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=12829.257, Time=2.30 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=12829.480, Time=1.74 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=12833.808, Time=1.02 sec
#  ARIMA(3,1,2)(2,0,0)[12] intercept   : AIC=12830.759, Time=2.34 sec
#  ARIMA(2,1,3)(2,0,0)[12] intercept   : AIC=12826.046, Time=3.27 sec
#  ARIMA(2,1,3)(1,0,0)[12] intercept   : AIC=inf, Time=2.77 sec
#  ARIMA(2,1,3)(2,0,1)[12] intercept   : AIC=12824.346, Time=3.84 sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=2.17 sec
#  ARIMA(2,1,3)(2,0,2)[12] intercept   : AIC=inf, Time=5.41 sec
#  ARIMA(2,1,3)(1,0,2)[12] intercept   : AIC=12824.972, Time=3.72 sec
#  ARIMA(1,1,3)(2,0,1)[12] intercept   : AIC=12830.332, Time=2.39 sec
#  ARIMA(3,1,3)(2,0,1)[12] intercept   : AIC=12825.864, Time=4.59 sec
#  ARIMA(2,1,4)(2,0,1)[12] intercept   : AIC=12831.061, Time=5.03 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=12829.426, Time=2.10 sec
#  ARIMA(1,1,4)(2,0,1)[12] intercept   : AIC=inf, Time=4.11 sec
#  ARIMA(3,1,2)(2,0,1)[12] intercept   : AIC=12831.857, Time=2.92 sec
#  ARIMA(3,1,4)(2,0,1)[12] intercept   : AIC=12827.922, Time=5.60 sec
#  ARIMA(2,1,3)(2,0,1)[12]             : AIC=12817.754, Time=2.45 sec
#  ARIMA(2,1,3)(1,0,1)[12]             : AIC=12815.778, Time=1.69 sec
#  ARIMA(2,1,3)(0,0,1)[12]             : AIC=12847.217, Time=1.33 sec
#  ARIMA(2,1,3)(1,0,0)[12]             : AIC=12834.252, Time=1.03 sec
#  ARIMA(2,1,3)(1,0,2)[12]             : AIC=12817.748, Time=2.26 sec
#  ARIMA(2,1,3)(0,0,0)[12]             : AIC=12875.515, Time=0.40 sec
#  ARIMA(2,1,3)(0,0,2)[12]             : AIC=12838.751, Time=2.16 sec
#  ARIMA(2,1,3)(2,0,0)[12]             : AIC=12824.640, Time=1.99 sec
#  ARIMA(2,1,3)(2,0,2)[12]             : AIC=12819.599, Time=4.32 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=12819.763, Time=0.68 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=12817.829, Time=1.23 sec
#  ARIMA(3,1,3)(1,0,1)[12]             : AIC=12800.290, Time=3.40 sec
#  ARIMA(3,1,3)(0,0,1)[12]             : AIC=12844.680, Time=1.48 sec
#  ARIMA(3,1,3)(1,0,0)[12]             : AIC=12832.383, Time=1.84 sec
#  ARIMA(3,1,3)(2,0,1)[12]             : AIC=12802.153, Time=5.24 sec
#  ARIMA(3,1,3)(1,0,2)[12]             : AIC=12801.693, Time=5.38 sec
#  ARIMA(3,1,3)(0,0,0)[12]             : AIC=12867.758, Time=0.44 sec
#  ARIMA(3,1,3)(0,0,2)[12]             : AIC=12836.595, Time=3.30 sec
#  ARIMA(3,1,3)(2,0,0)[12]             : AIC=12822.323, Time=3.33 sec
#  ARIMA(3,1,3)(2,0,2)[12]             : AIC=12804.110, Time=5.92 sec
#  ARIMA(3,1,2)(1,0,1)[12]             : AIC=12817.877, Time=1.57 sec
#  ARIMA(4,1,3)(1,0,1)[12]             : AIC=12808.354, Time=1.95 sec
#  ARIMA(3,1,4)(1,0,1)[12]             : AIC=12811.757, Time=3.16 sec
#  ARIMA(2,1,4)(1,0,1)[12]             : AIC=12800.355, Time=2.75 sec
#  ARIMA(4,1,2)(1,0,1)[12]             : AIC=12813.623, Time=1.66 sec
#  ARIMA(4,1,4)(1,0,1)[12]             : AIC=12812.830, Time=2.42 sec
#  ARIMA(3,1,3)(1,0,1)[12] intercept   : AIC=12826.402, Time=3.16 sec
#
# Best model:  ARIMA(3,1,3)(1,0,1)[12]
# Total fit time: 128.238 seconds
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  300
# Model:             SARIMAX(3, 1, 3)x(1, 0, [1], 12)   Log Likelihood               -6391.145
# Date:                              Thu, 26 Jun 2025   AIC                          12800.290
# Time:                                      19:33:47   BIC                          12833.594
# Sample:                                  01-01-1970   HQIC                         12813.620
#                                        - 01-01-1970
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3628      0.085     16.005      0.000       1.196       1.530
# ar.L2         -0.8342      0.102     -8.213      0.000      -1.033      -0.635
# ar.L3          0.0316      0.076      0.413      0.679      -0.118       0.181
# ma.L1         -2.1300      0.073    -29.356      0.000      -2.272      -1.988
# ma.L2          1.9671      0.099     19.811      0.000       1.772       2.162
# ma.L3         -0.7643      0.051    -14.846      0.000      -0.865      -0.663
# ar.S.L12       0.9021      0.069     13.152      0.000       0.768       1.037
# ma.S.L12      -0.6574      0.094     -6.995      0.000      -0.842      -0.473
# sigma2      2.746e+17   2.97e-19   9.25e+35      0.000    2.75e+17    2.75e+17
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               757.37
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):              46.07   Skew:                             0.92
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.92e+52. Standard errors may be unstable.

# %%
# ⚠️ Ton y_train, exog_train, y_test, exog_test doivent être déjà définis

# Définir et ajuster le modèle
model = SARIMAX(
    y_train,
    exog=exog_train,
    order=(3, 1, 3),         # Tu peux adapter ces valeurs
    seasonal_order=(1, 0, 1, 12),  # Pour la saisonnalité mensuelle
    enforce_stationarity=False,
    enforce_invertibility=False
)

results = model.fit(disp=False)
print(results.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                             Recettes   No. Observations:                  300
# Model:             SARIMAX(3, 1, 3)x(1, 0, [1], 12)   Log Likelihood               -6052.744
# Date:                              Thu, 26 Jun 2025   AIC                          12127.488
# Time:                                      19:48:17   BIC                          12167.588
# Sample:                                  01-01-1970   HQIC                         12143.567
#                                        - 01-01-1970
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# IPC        -8.268e+06   6.34e-09   -1.3e+15      0.000   -8.27e+06   -8.27e+06
# Change     -4.061e+06   2.15e-08  -1.89e+14      0.000   -4.06e+06   -4.06e+06
# ar.L1         -0.1739      0.236     -0.737      0.461      -0.636       0.288
# ar.L2         -0.4847      0.237     -2.045      0.041      -0.949      -0.020
# ar.L3          0.2207      0.072      3.073      0.002       0.080       0.361
# ma.L1         -0.5854      0.225     -2.607      0.009      -1.026      -0.145
# ma.L2          0.2587      0.212      1.220      0.223      -0.157       0.674
# ma.L3         -0.4704      0.194     -2.426      0.015      -0.850      -0.090
# ar.S.L12       1.0793      0.023     47.182      0.000       1.034       1.124
# ma.S.L12      -0.8335      0.045    -18.327      0.000      -0.923      -0.744
# sigma2      2.751e+17   1.31e-18   2.09e+35      0.000    2.75e+17    2.75e+17
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               755.24
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):              25.71   Skew:                             1.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.12e+49. Standard errors may be unstable.

# %%
pred = results.get_forecast(steps=12, exog=exog_test)
pred_mean = pred.predicted_mean
pred_ci = pred.conf_int()

plt.figure(figsize=(12,6))
plt.plot(y_train, label='Training')
plt.plot(test['Recettes'], label='Test (observed)', color='green')
plt.plot(pred_mean, label='Forecast', color='red')
plt.fill_between(pred_ci.index, pred_ci.iloc[:, 0], pred_ci.iloc[:, 1], color='pink', alpha=0.3)
plt.title('Prévision SARIMAX avec auto_arima')
plt.xlabel('Date')
plt.ylabel('Recettes')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 🔹 Prédictions sur l'ensemble d'entraînement
train_pred = stepwise_model.predict(n_periods=len(y_train), exogenous=exog_train)

# 🔹 Prédictions sur l'ensemble de test
forecast_test, confint = stepwise_model.predict(n_periods=12, exogenous=exog_test, return_conf_int=True)

# 🔹 Construction des index pour prédictions
train_index = y_train.index
test_index = y_test.index

# 🔹 Séries pandas
train_pred_series = pd.Series(train_pred, index=train_index)
forecast_series = pd.Series(forecast_test, index=test_index)
lower_series = pd.Series(confint[:, 0], index=test_index)
upper_series = pd.Series(confint[:, 1], index=test_index)

# 🔹 Tracer
plt.figure(figsize=(14,6))

plt.plot(y_train, label='Observed Train', color='blue')
plt.plot(train_pred_series, label='Predicted Train', color='orange')
plt.plot(y_test, label='Observed Test', color='green')
plt.plot(forecast_series, label='Forecast Test', color='red')
plt.fill_between(test_index, lower_series, upper_series, color='pink', alpha=0.3)
plt.title('Prévision Recettes différenciées — Train & Test')
plt.xlabel('Date')
plt.ylabel('dRecettes')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
